# %%
#do imports
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
data="/home/richard/Downloads/New Wave/mali/bank-user-churn.csv"
dataFrame = pd.read_csv(data)

# %%
dataFrame = pd.read_csv(data)

# %%
dataFrame
# Out:
#        RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0              1    15634602   Hargrave          619    France  Female  42.0
# 1              2    15647311       Hill          608     Spain  Female  41.0
# 2              3    15619304       Onio          502    France  Female  42.0
# 3              4    15701354       Boni          699    France  Female  39.0
# 4              5    15737888   Mitchell          850     Spain  Female  43.0
# ...          ...         ...        ...          ...       ...     ...   ...
# 9997        9998    15584532        Liu          709    France  Female  36.0
# 9998        9999    15682355  Sabbatini          772   Germany    Male  42.0
# 9999        9999    15682355  Sabbatini          772   Germany    Male  42.0
# 10000      10000    15628319     Walker          792    France  Female  28.0
# 10001      10000    15628319     Walker          792    France  Female  28.0
#
# ...

# %%
#view first 10 data
dataFrame.head().T
# Out:
#                          0          1          2         3          4
# RowNumber                1          2          3         4          5
# CustomerId        15634602   15647311   15619304  15701354   15737888
# Surname           Hargrave       Hill       Onio      Boni   Mitchell
# CreditScore            619        608        502       699        850
# Geography           France      Spain     France    France      Spain
# Gender              Female     Female     Female    Female     Female
# Age                   42.0       41.0       42.0      39.0       43.0
# Tenure                   2          1          8         1          2
# Balance                0.0   83807.86   159660.8       0.0  125510.82
# NumOfProducts            1          1          3         2          1
# HasCrCard              1.0        0.0        1.0       0.0        NaN
# IsActiveMember         1.0        1.0        0.0       0.0        1.0
# ...

# %%
dataFrame.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                float64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard          float64
# IsActiveMember     float64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
#Replace space with underscore
dataFrame.columns = dataFrame.columns.str.lower().str.replace(' ','_')
dataFrame.columns
dataFrameColumns = list(dataFrame.columns)

#Get non-numeric columns
categoricalColumns = list(dataFrame.dtypes[dataFrame.dtypes == 'object'].index)
categoricalColumns.remove('surname')

#Get numerical columns
numericalColumns = list(filter(lambda x: x not in categoricalColumns, dataFrameColumns))
numericalColumns.remove('surname')
numericalColumns.remove('exited')

print(numericalColumns)


for c in categoricalColumns:
    dataFrame[c] = dataFrame[c].str.lower().str.replace(' ', '_')
# Out:
# ['rownumber', 'customerid', 'creditscore', 'age', 'tenure', 'balance', 'numofproducts', 'hascrcard', 'isactivemember', 'estimatedsalary']

# %%
#view rows with null values
dataFrame[dataFrame.isnull().any(axis=1)]
# Out:
#    rownumber  customerid   surname  creditscore geography  gender   age  \
# 4          5    15737888  Mitchell          850     spain  female  43.0
# 6          7    15592531  Bartlett          822       NaN    male  50.0
# 8          9    15792365        He          501    france    male  44.0
# 9         10    15592389        H?          684    france    male   NaN
#
#    tenure    balance  numofproducts  hascrcard  isactivemember  \
# 4       2  125510.82              1        NaN             1.0
# 6       7       0.00              2        1.0             1.0
# 8       4  142051.07              2        0.0             NaN
# 9       2  134603.88              1        1.0             1.0
#
#    estimatedsalary  exited
# 4         79084.10       0
# 6         10062.80       0
# 8         74940.50       0
# 9         71725.73       0

# %%
dataFrame = dataFrame.fillna(0)

# %%
dataFrame[dataFrame.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [rownumber, customerid, surname, creditscore, geography, gender, age, tenure, balance, numofproducts, hascrcard, isactivemember, estimatedsalary, exited]
# Index: []

# %%
from sklearn.model_selection import train_test_split

# %%
#use the train test split to have the data 
dataFrameFullTrain, dataFrameTest = train_test_split(dataFrame,test_size=0.2,random_state=1)
dataFrameTrain, dataFrameValidate = train_test_split(dataFrameFullTrain,test_size=0.25,random_state=1)
dataFrameTrain.reset_index(drop=True)
dataFrameTest.reset_index(drop=True)
dataFrameValidate.reset_index(drop=True)
# Out:
#       rownumber  customerid     surname  creditscore geography  gender   age  \
# 0          9719    15704053       T'ang          710     spain    male  62.0
# 1          1896    15649418      Krylov          776    france  female  29.0
# 2          4088    15659962    McIntosh          637    france    male  60.0
# 3          3056    15602373       White          812    france    male  44.0
# 4          3737    15607748     Bennett          498   germany    male  37.0
# ...         ...         ...         ...          ...       ...     ...   ...
# 1996       6232    15729238        Peng          631   germany    male  48.0
# 1997       9654    15735799  Maconochie          527   germany    male  58.0
# 1998       8301    15802625       Hardy          733   germany    male  48.0
# 1999       1312    15750497       Longo          850    france  female  37.0
# 2000       1314    15576602    Lawrence          809    france    male  38.0
#
# ...

# %%
len(dataFrameTrain), len(dataFrameTest), len(dataFrameValidate)
# Out:
# (6000, 2001, 2001)

# %%
yTrain = dataFrameTrain.exited.values
yValidate = dataFrameValidate.exited.values
yTest = dataFrameTest.exited.values

# %%
del dataFrameTest['exited']
del dataFrameValidate['exited']
del dataFrameTrain['exited']

# %%
dataFrameValidate
# Out:
#       rownumber  customerid     surname  creditscore geography  gender   age  \
# 9718       9719    15704053       T'ang          710     spain    male  62.0
# 1895       1896    15649418      Krylov          776    france  female  29.0
# 4087       4088    15659962    McIntosh          637    france    male  60.0
# 3055       3056    15602373       White          812    france    male  44.0
# 3736       3737    15607748     Bennett          498   germany    male  37.0
# ...         ...         ...         ...          ...       ...     ...   ...
# 6231       6232    15729238        Peng          631   germany    male  48.0
# 9653       9654    15735799  Maconochie          527   germany    male  58.0
# 8300       8301    15802625       Hardy          733   germany    male  48.0
# 1311       1312    15750497       Longo          850    france  female  37.0
# 1313       1314    15576602    Lawrence          809    france    male  38.0
#
# ...

# %%
dataFrameFullTrain.exited
# Out:
# 2722    0
# 2954    0
# 6400    0
# 9861    0
# 2157    0
#        ..
# 2895    0
# 7813    1
# 905     1
# 5192    0
# 235     1
# Name: exited, Length: 8001, dtype: int64

# %%
dataFrameFullTrain[categoricalColumns].nunique()
# Out:
# geography    3
# gender       2
# dtype: int64

# %%
globalChurn = dataFrameFullTrain.exited.mean()
globalChurn
# Out:
# np.float64(0.20647419072615922)

# %%
dataFrameFullTrain[categoricalColumns].nunique()
# Out:
# geography    3
# gender       2
# dtype: int64

# %%
dataFrameFullTrain.groupby('geography').sum()
# Out:
#            rownumber   customerid  \
# geography
# france      20271963  62860830643
# germany     10084710  31571349122
# spain        9857538  31117829217
#
#                                                      surname  creditscore  \
# geography
# france     ConwayShoobridgeVictorUwakweChungMaoMikkelsenC...      2602340
# germany    LuccianoSoubeiranLiuT'aoHillLewisTateContiPatr...      1310901
# spain      CollierCraigObijiakuL?GrayRaymondWoodTrevisani...      1292058
#
#                                                       gender        age  \
# geography
# france     femalefemalemalefemalemalemalefemalemalefemale...  154763.00
# germany    malemalemalefemalemalemalefemalefemalefemalema...   80370.44
# spain      femalemalemalefemalefemalefemalemalemalemalefe...   77453.25
#
#            tenure       balance  numofproducts  hascrcard  isactivemember  \
# geography
# france      20096  2.494232e+08           6142     2857.0          2057.0
# ...

# %%
franceExitRate = dataFrameFullTrain[dataFrameFullTrain.geography == 'france'].exited.mean()
franceExitRate
# Out:
# np.float64(0.16100848726909636)

# %%
germanyExitRate = dataFrameFullTrain[dataFrameFullTrain.geography == 'germany'].exited.mean()
germanyExitRate
# Out:
# np.float64(0.33300198807157055)

# %%
spainExitRate = dataFrameFullTrain[dataFrameFullTrain.geography == 'spain'].exited.mean()
spainExitRate
# Out:
# np.float64(0.16994452849218356)

# %%
maleExitRate = dataFrameFullTrain[dataFrameFullTrain.gender == 'male'].exited.mean()
maleExitRate
# Out:
# np.float64(0.167816091954023)

# %%
femaleExitRate = dataFrameFullTrain[dataFrameFullTrain.gender == 'female'].exited.mean()
femaleExitRate
# Out:
# np.float64(0.2525335524513832)

# %%
#Get the risk factor and global & group difference to know the churn rate
for c in categoricalColumns:
    print(c)
    dataFrameGroup = dataFrameFullTrain.groupby(c).exited.agg(['mean','count'])
    dataFrameGroup['diff'] = dataFrameGroup['mean'] - globalChurn
    dataFrameGroup['risk'] = dataFrameGroup['mean'] / globalChurn
    display(dataFrameGroup)
    print()
    print()
# Out:
# geography
#                mean  count      diff      risk
# geography
# france     0.161008   4006 -0.045466  0.779800
# germany    0.333002   2012  0.126528  1.612802
# spain      0.169945   1983 -0.036530  0.823079
# gender
#             mean  count      diff      risk
# gender
# female  0.252534   3651  0.046059  1.223076
# male    0.167816   4350 -0.038658  0.812770

# %%
from sklearn.metrics import mutual_info_score

# %%
def calculate_mi(series):
    return mutual_info_score(series, dataFrameFullTrain.exited)

dataFrameMutualInformation = dataFrameFullTrain[categoricalColumns].apply(calculate_mi)
dataFrameMutualInformation = dataFrameMutualInformation.sort_values(ascending=False).to_frame(name='MI')


display(dataFrameMutualInformation.head())
display(dataFrameMutualInformation.tail())
# Out:
#                  MI
# geography  0.015303
# gender     0.005416
#                  MI
# geography  0.015303
# gender     0.005416

# %%
dataFrameFullTrain[numericalColumns]
# Out:
#       rownumber  customerid  creditscore   age  tenure    balance  \
# 2722       2723    15675422          544  32.0       9  110728.39
# 2954       2955    15775562          538  33.0       5       0.00
# 6400       6401    15585907          676  30.0       5       0.00
# 9861       9862    15798341          544  38.0       8       0.00
# 2157       2158    15750649          744  44.0       3       0.00
# ...         ...         ...          ...   ...     ...        ...
# 2895       2896    15646859          621  47.0       7  107363.29
# 7813       7814    15592751          684  63.0       3   81245.79
# 905         906    15675964          672  45.0       9       0.00
# 5192       5193    15607884          663  39.0       8       0.00
# 235         236    15772896          763  42.0       6  100160.75
#
#       numofproducts  hascrcard  isactivemember  estimatedsalary
# 2722              1        1.0             1.0         14559.62
# ...

# %%
dataFrameFullTrain[numericalColumns].corrwith(dataFrameFullTrain.exited)
# Out:
# rownumber         -0.022117
# customerid        -0.008211
# creditscore       -0.022891
# age                0.284385
# tenure            -0.012237
# balance            0.125406
# numofproducts     -0.042526
# hascrcard         -0.011951
# isactivemember    -0.149958
# estimatedsalary    0.010625
# dtype: float64

# %%
#This shows positive correlation
dataFrameFullTrain[dataFrameFullTrain.balance <= 150000].exited.mean()
# Out:
# np.float64(0.2038498822877718)

# %%
#This shows negatie correlation
dataFrameFullTrain[dataFrameFullTrain.tenure <= 5].exited.mean()
# Out:
# np.float64(0.21044267877412032)

# %%
#implementing one hot encoding
from sklearn.feature_extraction import DictVectorizer

# %%
categoricalColumns
numericalColumns
# Out:
# ['rownumber',
#  'customerid',
#  'creditscore',
#  'age',
#  'tenure',
#  'balance',
#  'numofproducts',
#  'hascrcard',
#  'isactivemember',
#  'estimatedsalary']

# %%
#Convert dataFrameTrain values to  a dictionary
trainDictionary = dataFrameTrain[categoricalColumns+numericalColumns].to_dict(orient='records')

# %%
trainDictionary[0]
# Out:
# {'geography': 'france',
#  'gender': 'female',
#  'rownumber': 8763,
#  'customerid': 15765173,
#  'creditscore': 350,
#  'age': 60.0,
#  'tenure': 3,
#  'balance': 0.0,
#  'numofproducts': 1,
#  'hascrcard': 0.0,
#  'isactivemember': 0.0,
#  'estimatedsalary': 113796.15}

# %%
dictionaryVectorizer = DictVectorizer(sparse=False)

# %%
dictionaryVectorizer.fit(trainDictionary)
# Out:
# DictVectorizer(sparse=False)

# %%
xTrain = dictionaryVectorizer.fit_transform(trainDictionary)

# %%
validateDictionary = dataFrameValidate[categoricalColumns+numericalColumns].to_dict(orient='records')

# %%
xValidate = dictionaryVectorizer.transform(validateDictionary)

# %% [markdown]
# data.shape
